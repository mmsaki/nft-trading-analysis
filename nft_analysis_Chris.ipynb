# %% [markdown]
# <img src="https://media2.giphy.com/media/JTV3ciE3YTDycJXhmq/giphy.gif?cid=ecf05e47e01en4yfdxy8feugp8cfur80fovlpp01u38dssnk&rid=giphy.gif&ct=g" alt="ether" width="100%"/>

# %% [markdown]
# ## NFTs data Analysis

# %%
# Import dependancies

import os
import requests
import pandas as pd
import json
from dotenv import load_dotenv

# %%
# Load .env enviroment variables
load_dotenv()
# Out:
# True

# %%
# create variable for api key 
covalent_API_KEY = os.getenv("Covalent-API-KEY")

# %%
##TEMP VALIDATE KEY#
type(covalent_API_KEY)
# Out:
# str

# %% [markdown]
# ## Get NFT Token IDS

# %%
# Append url for our api
url = "https://api.covalenthq.com/v1"
chain_id = "/1"

# Add search queries to api url
contract_address = "/0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB"
api_key = "/?key=" + covalent_API_KEY

url_tokens = url + chain_id + "/tokens" + contract_address + "/nft_token_ids" + api_key #+ "&format=csv"

# Create variale for our requests data
nft_tokens = requests.get(url_tokens).json()

# Display dataframe
token_IDS = pd.DataFrame(nft_tokens['data']['items'])
token_IDS.head()
# Out:
#    contract_decimals contract_name contract_ticker_symbol  \
# 0                  0   CRYPTOPUNKS                      Ͼ
# 1                  0   CRYPTOPUNKS                      Ͼ
# 2                  0   CRYPTOPUNKS                      Ͼ
# 3                  0   CRYPTOPUNKS                      Ͼ
# 4                  0   CRYPTOPUNKS                      Ͼ
#
#                              contract_address supports_erc  \
# 0  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb         None
# 1  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb         None
# 2  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb         None
# 3  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb         None
# 4  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb         None
#
#                                             logo_url token_id
# 0  https://logos.covalenthq.com/tokens/0xb47e3cd8...        0
# 1  https://logos.covalenthq.com/tokens/0xb47e3cd8...        1
# 2  https://logos.covalenthq.com/tokens/0xb47e3cd8...        2
# 3  https://logos.covalenthq.com/tokens/0xb47e3cd8...        3
# 4  https://logos.covalenthq.com/tokens/0xb47e3cd8...        4

# %% [markdown]
# ## Get NFT Contract Transactions

# %%
# Create contract address varibles
contract_address = "/0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB"
token_ID = "/200"

# Create search queries for api
url_transactins = url + chain_id + "/tokens" + contract_address + "/nft_transactions" + token_ID + api_key
nft_transactions = requests.get(url_transactins).json()

# Display data
transactions_df = pd.DataFrame(nft_transactions['data']['items'][0]['nft_transactions'][0])
transactions_df.head()
# Out:
#         block_signed_at  block_height  \
# 0  2022-03-17T03:51:37Z      14401717
# 1  2022-03-17T03:51:37Z      14401717
#
#                                              tx_hash  tx_offset  successful  \
# 0  0x5b0ee618e7eef1baefc510019edb2c9b5962ee1730e4...          6        True
# 1  0x5b0ee618e7eef1baefc510019edb2c9b5962ee1730e4...          6        True
#
#                                  from_address from_address_label  \
# 0  0xc352b534e8b987e036a93539fd6897f53488e56a               None
# 1  0xc352b534e8b987e036a93539fd6897f53488e56a               None
#
#                                    to_address to_address_label value  \
# 0  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb  CRYPTOPUNKS (Ͼ)     0
# 1  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb  CRYPTOPUNKS (Ͼ)     0
#
#    value_quote  gas_offered  gas_spent    gas_price         fees_paid  \
# 0          0.0       400000      48279  60000000000  2896740000000000
# 1          0.0       400000      48279  60000000000  2896740000000000
#
#    gas_quote  gas_quote_rate  \
# 0   8.196203      2829.45752
# 1   8.196203      2829.45752
#
#                                           log_events
# 0  {'block_signed_at': '2022-03-17T03:51:37Z', 'b...
# 1  {'block_signed_at': '2022-03-17T03:51:37Z', 'b...

# %% [markdown]
# ## GET Address Balances

# %%
# Create account addresses
address = "/msaki.eth"

# Search api to return data
url_bal = url + chain_id + "/address" + address + "/balances_v2" + api_key
balances = requests.get(url_bal).json()

# Display data
balance_df = pd.DataFrame(balances['data']['items'])
balance_df.head()
# Out:
#    contract_decimals contract_name contract_ticker_symbol  \
# 0                 18         Ether                    ETH
# 1                 18       ApeCoin                    APE
# 2                 18     Bemil.io                     BEM
# 3                  6      USD Coin                   USDC
# 4                  6    Tether USD                   USDT
#
#                              contract_address supports_erc  \
# 0  0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee         None
# 1  0x4d224452801aced8b2f0aebe155379bb5d594381      [erc20]
# 2  0x3102931098e75111a6f57cdf9a3e68dd007e5dd1      [erc20]
# 3  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48      [erc20]
# 4  0xdac17f958d2ee523a2206206994597c13d831ec7      [erc20]
#
#                                             logo_url   last_transferred_at  \
# 0  https://www.covalenthq.com/static/images/icons...                  None
# 1  https://logos.covalenthq.com/tokens/1/0x4d2244...  2022-04-25T23:55:43Z
# 2  https://logos.covalenthq.com/tokens/1/0x310293...  2021-11-06T22:49:45Z
# 3  https://logos.covalenthq.com/tokens/1/0xa0b869...  2021-11-20T09:12:25Z
# 4  https://logos.covalenthq.com/tokens/1/0xdac17f...  2022-04-23T15:21:23Z
#
#              type                  balance              balance_24h  \
# 0  cryptocurrency  11923112004967972325026  11627900631422460178004
# 1  cryptocurrency   4387375327825867762092   4387375327825867762092
# 2  cryptocurrency  10238000000000000000000  10238000000000000000000
# 3      stablecoin               2545889125               2545889125
# 4      stablecoin               1142525387               1142525387
#
#     quote_rate  quote_rate_24h         quote     quote_24h nft_data
# 0  2885.521000     2863.487300  3.440439e+07  3.329635e+07     None
# 1    19.957893       19.362696  8.756277e+04  8.495141e+04     None
# 2     0.391597             NaN  4.009175e+03           NaN     None
# 3     0.999352        0.993984  2.544238e+03  2.530572e+03     None
# 4     1.000139        0.996329  1.142684e+03  1.138331e+03     None

# %% [markdown]
# ## Get historical portfolio value over time

# %%
# Create account addresses 
address = "/msaki.eth"

# Search api for address and portfolio data
url_portfolio = url + chain_id + "/address" + address + "/portfolio_v2" + api_key
portfolio = requests.get(url_portfolio).json()

# Display data
portfolio_df = pd.DataFrame(portfolio['data']['items'][0]['holdings'])

# %%
portfolio_df.head()
# Out:
#               timestamp  quote_rate  \
# 0  2022-04-28T00:00:00Z   2885.5210
# 1  2022-04-27T00:00:00Z   2863.4873
# 2  2022-04-26T00:00:00Z   2979.3630
# 3  2022-04-25T00:00:00Z   2933.9536
# 4  2022-04-24T00:00:00Z   2928.9316
#
#                                                 open  \
# 0  {'balance': '11923112004967972325026', 'quote'...
# 1  {'balance': '11923112004967972325026', 'quote'...
# 2  {'balance': '11923112004967972325026', 'quote'...
# 3  {'balance': '11923112004967972325026', 'quote'...
# 4  {'balance': '11923112004967972325026', 'quote'...
#
#                                                 high  \
# 0  {'balance': '11923112004967972325026', 'quote'...
# 1  {'balance': '11923112004967972325026', 'quote'...
# 2  {'balance': '11923112004967972325026', 'quote'...
# 3  {'balance': '11923112004967972325026', 'quote'...
# 4  {'balance': '11923112004967972325026', 'quote'...
#
#                                                  low  \
# 0  {'balance': '11923112004967972325026', 'quote'...
# 1  {'balance': '11923112004967972325026', 'quote'...
# 2  {'balance': '11923112004967972325026', 'quote'...
# 3  {'balance': '11923112004967972325026', 'quote'...
# 4  {'balance': '11923112004967972325026', 'quote'...
#
#                                                close
# 0  {'balance': '11923112004967972325026', 'quote'...
# 1  {'balance': '11923112004967972325026', 'quote'...
# 2  {'balance': '11923112004967972325026', 'quote'...
# 3  {'balance': '11923112004967972325026', 'quote'...
# 4  {'balance': '11923112004967972325026', 'quote'...

# %% [markdown]
# ## Get Market Place data

# %%
# Create global varial for marketplace
url_global_view = url + chain_id + "/nft_market" + api_key
global_view = requests.get(url_global_view).json()

# Review data as dataframe
global_view_df = pd.DataFrame(global_view['data']['items'])
global_view_df.head(10)
# Out:
#    chain_id             collection_name  \
# 0         1                     Rarible
# 1         1                   Town Star
# 2         1  Fantasy Islands - Sandbox
# 3         1           BoredApeYachtClub
# 4         1             Sandbox's LANDs
# 5         1                     Meebits
# 6         1                  Art Blocks
# 7         1          MutantApeYachtClub
# 8         1                       Azuki
# 9         1                      CloneX
#
#                            collection_address          volume_wei_24h  \
# 0  0xd07dc4262bcdbf85190c01c996b4c06a461d2430     1000000000000000000
# 1  0xc36cf0cfcb5d905b8b513860db0cfe63f6cf9f5c                       0
# 2  0x68aea268f92b715e073d2f5170039faa4b94a47b                       0
# 3  0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d   743000000000000000000
# 4  0x50f5474724e0ee42d9a4e711ccfb275809fd6d4a     2390000000000000000
# 5  0x7bd29408f11d2bfc23c34f18275bbf23bb716bc7    40190000000000000000
# 6  0xa7d8d9ef8d8ce8992df33d8b8cf4aebabd5bd270   161312079990000000000
# 7  0x60e4d786628fea6478f785a6d7e704777c86a7c6   711030000000000000000
# 8  0xed5af388653567af2f388e6224dc7c4b3241c544  4876178000000000000000
# 9  0x49cf6f5d44e70224e2e23fdcdd2c053f30ada28b  1204118400000000000000
#
#    volume_quote_24h     avg_volume_wei_24h  avg_volume_quote_24h  \
# 0      3.477595e+03    1000000000000000000             3477.5955
# 1      0.000000e+00                      0                0.0000
# 2      0.000000e+00                      0                0.0000
# 3      2.583854e+06  185750000000000000000           645963.4000
# 4      8.311453e+03    2390000000000000000             8311.4530
# 5      1.397646e+05    5023750000000000000            17470.5700
# 6      5.609782e+05    1772660219670330000             6164.5950
# 7      2.472675e+06   25393928571428600000            88309.8100
# 8      1.695737e+07   35334623188405800000           122879.5200
# 9      4.187437e+06   20760662068965500000            72197.1900
#
#   contract_deployment_at                   market_cap_wei  market_cap_quote  \
# 0   2020-05-27T11:49:56Z  6269271254011360000000000000000      2.180199e+16
# 1   2020-06-04T10:10:10Z       35996080896093600000000000      1.251798e+11
# 2   2021-08-20T00:00:55Z        1153800000000000000000000      4.012450e+09
# 3   2021-04-22T03:03:16Z         311400386483699000000000      1.082925e+09
# 4   2019-12-04T07:51:55Z         263567420745161000000000      9.165809e+08
# 5   2021-05-03T00:49:32Z         237309568302152000000000      8.252667e+08
# 6   2020-12-12T08:59:58Z         213785789663137000000000      7.434605e+08
# 7   2021-08-28T23:59:15Z         180697272256570000000000      6.283920e+08
# 8   2022-01-10T05:19:57Z         167638580283958000000000      5.829791e+08
# 9   2021-12-12T13:50:39Z         147850229797283000000000      5.141633e+08
#
#    ...      floor_price_wei_7d  floor_price_quote_7d  gas_quote_rate  \
# 0  ...      137816704081529000          4.792708e+02       3477.5955
# 1  ...      865000000000000000          3.008120e+03       3477.5955
# 2  ...  7770666666666670000000          2.702324e+07       3477.5955
# 3  ...   118649928843994000000          4.126165e+05       3477.5955
# 4  ...     2330554166666670000          8.104725e+03       3477.5955
# 5  ...   102961367689247000000          3.580580e+05       3477.5955
# 6  ...     1156779546260830000          4.022811e+03       3477.5955
# 7  ...    24275317688972800000          8.441973e+04       3477.5955
# 8  ...    41440013247272700000          1.441116e+05       3477.5955
# 9  ...    19442649804911700000          6.761367e+04       3477.5955
#
#   quote_currency  opening_date first_nft_image_token_id  \
# 0            USD    2022-04-03                        1
# 1            USD    2022-04-03                     None
# 2            USD    2022-04-03                        1
# 3            USD    2022-04-03                        0
# 4            USD    2022-04-03                       45
# 5            USD    2022-04-03                        1
# 6            USD    2022-04-03                  3000000
# 7            USD    2022-04-03                        0
# 8            USD    2022-04-03                        0
# 9            USD    2022-04-03                        1
#
#                                      first_nft_image  \
# 0  https://cloudflare-ipfs.com/ipfs/QmdU9h6dECWKR...
# 1                                               None
# 2  https://ipfs.io/ipfs/QmPqJyCtpQux4CZ4uVpJ9PdFv...
# 3  https://ipfs.io/ipfs/QmRRPWG96cmgTn2qSzjwr2qvf...
# 4  https://api.sandbox.game/lands/afc9cb8b-c281-4...
# 5  http://meebits.larvalabs.com/meebitimages/char...
# 6             https://api.artblocks.io/image/3000000
# 7  https://ipfs.io/ipfs/QmURua8bNrAwX76Tp6G9t6Los...
# 8  https://azuki-prereveal.s3.us-west-1.amazonaws...
# 9       https://clonex-assets.rtfkt.com/images/1.png
#
#                                  first_nft_image_256  \
# 0  https://image-proxy.svc.prod.covalenthq.com/25...
# 1                                               None
# 2  https://image-proxy.svc.prod.covalenthq.com/25...
# 3  https://image-proxy.svc.prod.covalenthq.com/25...
# 4  https://image-proxy.svc.prod.covalenthq.com/25...
# 5  https://image-proxy.svc.prod.covalenthq.com/25...
# 6  https://image-proxy.svc.prod.covalenthq.com/25...
# 7  https://image-proxy.svc.prod.covalenthq.com/25...
# 8  https://image-proxy.svc.prod.covalenthq.com/25...
# 9  https://image-proxy.svc.prod.covalenthq.com/25...
#
#                                  first_nft_image_512  \
# 0  https://image-proxy.svc.prod.covalenthq.com/51...
# 1                                               None
# 2  https://image-proxy.svc.prod.covalenthq.com/51...
# 3  https://image-proxy.svc.prod.covalenthq.com/51...
# 4  https://image-proxy.svc.prod.covalenthq.com/51...
# 5  https://image-proxy.svc.prod.covalenthq.com/51...
# 6  https://image-proxy.svc.prod.covalenthq.com/51...
# 7  https://image-proxy.svc.prod.covalenthq.com/51...
# 8  https://image-proxy.svc.prod.covalenthq.com/51...
# 9  https://image-proxy.svc.prod.covalenthq.com/51...
#
#                                 first_nft_image_1024
# 0  https://image-proxy.svc.prod.covalenthq.com/10...
# 1                                               None
# 2  https://image-proxy.svc.prod.covalenthq.com/10...
# 3  https://image-proxy.svc.prod.covalenthq.com/10...
# 4  https://image-proxy.svc.prod.covalenthq.com/10...
# 5  https://image-proxy.svc.prod.covalenthq.com/10...
# 6  https://image-proxy.svc.prod.covalenthq.com/10...
# 7  https://image-proxy.svc.prod.covalenthq.com/10...
# 8  https://image-proxy.svc.prod.covalenthq.com/10...
# 9  https://image-proxy.svc.prod.covalenthq.com/10...
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Get Historical data for NFT collection

# %%
collection_address = ""

# %% [markdown]
# # TEST GIT PUSH BRANCH - CHRIS

# %% [markdown]
# # NFT Market Cap Detailed View

# %%
# Append url for our api
url = "https://api.covalenthq.com/v1"
chain_id = "/1"    #TEMP is it always chain1 for most part?
option = "/nft_market/collection"
# Add search queries to api url
contract_address = "/0xb47e3cd837dDF8e4c57F05d70Ab865de6e193BBB"   #Do we want to compare other contracts
currency = "/?quote-currency=USD"
format_output = "&format=JSON"
date_from ="&from=2022-01-01"
date_to = "&to=2022-04-25"

api_key = "&key=" + covalent_API_KEY

url_nft_market_cap_detail = url + chain_id + option + contract_address + currency + format_output + date_from + date_to  + api_key

# %%
nft_market_cap = requests.get(url_nft_market_cap_detail).json()

# %%
nft_market_cap_df = pd.DataFrame(nft_market_cap['data']['items'])

# %%
display(nft_market_cap_df.head())
display(nft_market_cap_df.tail())
# Out:
#    chain_id collection_name                          collection_address  \
# 0         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 1         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 2         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 3         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 4         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
#
#   collection_ticker_symbol opening_date         volume_wei_day  \
# 0                        Ͼ   2022-03-05  208000000000000000000
# 1                        Ͼ   2022-03-04  295890000000000000000
# 2                        Ͼ   2022-03-03  435130000000000000000
# 3                        Ͼ   2022-03-02  776300000000000000000
# 4                        Ͼ   2022-03-01  289340000000000000000
#
#    volume_quote_day average_volume_wei_day  average_volume_quote_day  \
# 0         551644.44   69333333333333300000                183881.480
# 1         840630.56   29589000000000000000                 84063.055
# 2        1278073.00   43513000000000000000                127807.300
# 3        2318514.80   70572727272727300000                210774.060
# 4         838124.90   36167500000000000000                104765.610
#
#    unique_token_ids_sold_count_day  ... fourth_nft_image_token_id  \
# 0                                3  ...                      None
# 1                               10  ...                      None
# 2                               10  ...                      None
# 3                               11  ...                      None
# 4                                7  ...                      None
#
#    fourth_nft_image  fourth_nft_image_256 fourth_nft_image_512  \
# 0              None                  None                 None
# 1              None                  None                 None
# 2              None                  None                 None
# 3              None                  None                 None
# 4              None                  None                 None
#
#   fourth_nft_image_1024 fifth_nft_image_token_id fifth_nft_image  \
# 0                  None                     None            None
# 1                  None                     None            None
# 2                  None                     None            None
# 3                  None                     None            None
# 4                  None                     None            None
#
#   fifth_nft_image_256 fifth_nft_image_512 fifth_nft_image_1024
# 0                None                None                 None
# 1                None                None                 None
# 2                None                None                 None
# 3                None                None                 None
# 4                None                None                 None
#
# [5 rows x 39 columns]
#     chain_id collection_name                          collection_address  \
# 59         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 60         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 61         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 62         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 63         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
#
#    collection_ticker_symbol opening_date          volume_wei_day  \
# 59                        Ͼ   2022-01-05   320890000000000000000
# 60                        Ͼ   2022-01-04   202140000000000000000
# 61                        Ͼ   2022-01-03   576410000000000000000
# 62                        Ͼ   2022-01-02   740900000000000000000
# 63                        Ͼ   2022-01-01  1221480000000000000000
#
#     volume_quote_day average_volume_wei_day  average_volume_quote_day  \
# 59         1202992.2   35654444444444400000                 133665.81
# 60          777186.0   50535000000000000000                 194296.50
# 61         2213638.8   64045555555555600000                 245959.86
# 62         2867750.2   74090000000000000000                 286775.03
# 63         4482141.5   50895000000000000000                 186755.89
#
#     unique_token_ids_sold_count_day  ... fourth_nft_image_token_id  \
# 59                                9  ...                      None
# 60                                3  ...                      None
# 61                                9  ...                      None
# 62                               10  ...                      None
# 63                               22  ...                      None
#
#     fourth_nft_image  fourth_nft_image_256 fourth_nft_image_512  \
# 59              None                  None                 None
# 60              None                  None                 None
# 61              None                  None                 None
# 62              None                  None                 None
# 63              None                  None                 None
#
#    fourth_nft_image_1024 fifth_nft_image_token_id fifth_nft_image  \
# 59                  None                     None            None
# 60                  None                     None            None
# 61                  None                     None            None
# 62                  None                     None            None
# 63                  None                     None            None
#
#    fifth_nft_image_256 fifth_nft_image_512 fifth_nft_image_1024
# 59                None                None                 None
# 60                None                None                 None
# 61                None                None                 None
# 62                None                None                 None
# 63                None                None                 None
#
# [5 rows x 39 columns]

# %%
nft_market_cap_df_edited = nft_market_cap_df.drop(columns=['fourth_nft_image_token_id','fourth_nft_image', 'fourth_nft_image_256','fourth_nft_image_512', 'fourth_nft_image_1024', 'fifth_nft_image_token_id','fifth_nft_image', 'fifth_nft_image_256', 'fifth_nft_image_512', 'fifth_nft_image_1024'])

# %%
display(nft_market_cap_df_edited.head())
display(nft_market_cap_df_edited.tail())
# Out:
#    chain_id collection_name                          collection_address  \
# 0         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 1         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 2         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 3         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 4         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
#
#   collection_ticker_symbol opening_date         volume_wei_day  \
# 0                        Ͼ   2022-03-05  208000000000000000000
# 1                        Ͼ   2022-03-04  295890000000000000000
# 2                        Ͼ   2022-03-03  435130000000000000000
# 3                        Ͼ   2022-03-02  776300000000000000000
# 4                        Ͼ   2022-03-01  289340000000000000000
#
#    volume_quote_day average_volume_wei_day  average_volume_quote_day  \
# 0         551644.44   69333333333333300000                183881.480
# 1         840630.56   29589000000000000000                 84063.055
# 2        1278073.00   43513000000000000000                127807.300
# 3        2318514.80   70572727272727300000                210774.060
# 4         838124.90   36167500000000000000                104765.610
#
#    unique_token_ids_sold_count_day  ... second_nft_image_token_id  \
# 0                                3  ...                      None
# 1                               10  ...                      None
# 2                               10  ...                      None
# 3                               11  ...                      None
# 4                                7  ...                      None
#
#    second_nft_image  second_nft_image_256 second_nft_image_512  \
# 0              None                  None                 None
# 1              None                  None                 None
# 2              None                  None                 None
# 3              None                  None                 None
# 4              None                  None                 None
#
#   second_nft_image_1024 third_nft_image_token_id third_nft_image  \
# 0                  None                     None            None
# 1                  None                     None            None
# 2                  None                     None            None
# 3                  None                     None            None
# 4                  None                     None            None
#
#   third_nft_image_256 third_nft_image_512 third_nft_image_1024
# 0                None                None                 None
# 1                None                None                 None
# 2                None                None                 None
# 3                None                None                 None
# 4                None                None                 None
#
# [5 rows x 29 columns]
#     chain_id collection_name                          collection_address  \
# 59         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 60         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 61         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 62         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
# 63         1     CRYPTOPUNKS  0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb
#
#    collection_ticker_symbol opening_date          volume_wei_day  \
# 59                        Ͼ   2022-01-05   320890000000000000000
# 60                        Ͼ   2022-01-04   202140000000000000000
# 61                        Ͼ   2022-01-03   576410000000000000000
# 62                        Ͼ   2022-01-02   740900000000000000000
# 63                        Ͼ   2022-01-01  1221480000000000000000
#
#     volume_quote_day average_volume_wei_day  average_volume_quote_day  \
# 59         1202992.2   35654444444444400000                 133665.81
# 60          777186.0   50535000000000000000                 194296.50
# 61         2213638.8   64045555555555600000                 245959.86
# 62         2867750.2   74090000000000000000                 286775.03
# 63         4482141.5   50895000000000000000                 186755.89
#
#     unique_token_ids_sold_count_day  ... second_nft_image_token_id  \
# 59                                9  ...                      None
# 60                                3  ...                      None
# 61                                9  ...                      None
# 62                               10  ...                      None
# 63                               22  ...                      None
#
#     second_nft_image  second_nft_image_256 second_nft_image_512  \
# 59              None                  None                 None
# 60              None                  None                 None
# 61              None                  None                 None
# 62              None                  None                 None
# 63              None                  None                 None
#
#    second_nft_image_1024 third_nft_image_token_id third_nft_image  \
# 59                  None                     None            None
# 60                  None                     None            None
# 61                  None                     None            None
# 62                  None                     None            None
# 63                  None                     None            None
#
#    third_nft_image_256 third_nft_image_512 third_nft_image_1024
# 59                None                None                 None
# 60                None                None                 None
# 61                None                None                 None
# 62                None                None                 None
# 63                None                None                 None
#
# [5 rows x 29 columns]
